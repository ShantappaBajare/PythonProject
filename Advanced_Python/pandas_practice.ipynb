# %%
import pandas as pd
import numpy as np

# %% [markdown]
# lets create excel data

# %%
data= {
    "Name" : ["shantappa","narasimha"],
    "ID" : [101,102]
}

# %% [markdown]
# lets save these in excel

# %%
df = pd.DataFrame(data)
df.to_excel("sample.xlsx", index=False)

print("sample sheet created")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.DataFrame(data)
#       2 df.to_excel("sample.xlsx", index=False)
#       4 print("sample sheet created")
#
# AttributeError: module 'pandas' has no attribute 'DataFrame'
